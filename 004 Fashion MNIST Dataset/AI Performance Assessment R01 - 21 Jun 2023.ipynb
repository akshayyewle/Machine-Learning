# %%
# !pip install ai-benchmark

# %%
# !python --version
# Out:
# Python 3.11.6

# %%
from ai_benchmark import AIBenchmark
from warnings import filterwarnings
filterwarnings('ignore')

# %%
benchmark = AIBenchmark()
# Out:
# >>   AI-Benchmark-v.0.1.2
# >>   Let the AI Games begin..
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\aksha\OneDrive\06 Data Science & Analytics\Github\Machine-Learning\04 Fashion MNIST Dataset\AI Performance Assessment R01 - 21 Jun 2023.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aksha/OneDrive/06%20Data%20Science%20%26%20Analytics/Github/Machine-Learning/04%20Fashion%20MNIST%20Dataset/AI%20Performance%20Assessment%20R01%20-%2021%20Jun%202023.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> benchmark = AIBenchmark()
#
# File c:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\ai_benchmark\__init__.py:18, in AIBenchmark.__init__(self, use_CPU, verbose_level)
#      15 if verbose_level > 0:
#      16     printIntro()
# ---> 18 np.warnings.filterwarnings('ignore')
#      20 try:
#      22     if verbose_level < 3:
#
# ...

# %%
results = benchmark.run(precision='normal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aksha\OneDrive\06 Data Science & Analytics\Github\Machine-Learning\04 Fashion MNIST Dataset\AI Performance Assessment R01 - 21 Jun 2023.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aksha/OneDrive/06%20Data%20Science%20%26%20Analytics/Github/Machine-Learning/04%20Fashion%20MNIST%20Dataset/AI%20Performance%20Assessment%20R01%20-%2021%20Jun%202023.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> results = benchmark.run(precision='normal')
#
# NameError: name 'benchmark' is not defined

# %%
# Google Colab
# Device Inference Score: 15320
# Device Training Score: 16565
# Device AI Score: 31885

# Dell Inspiron 5430 Core i7-1360P
