# %% [markdown]
# ## **Setup**

# %%
from sklearn.datasets import load_sample_images
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Data Import**

# %%
images = load_sample_images()['images']

# %%
plt.figure(figsize=(8,7))

plt.subplot(1,2,1)
plt.imshow(images[0])

plt.subplot(1,2,2)
plt.imshow(images[1])

plt.show()

# %% [markdown]
# ## **Center Crop & Rescaling Layer**

# %%
images = tf.keras.layers.CenterCrop(height=70,width=120)(images)
images = tf.keras.layers.Rescaling(scale=1/255)(images)

images.shape
# Out:
# TensorShape([2, 70, 120, 3])

# %%
plt.figure(figsize=(8,7))

plt.subplot(1,2,1)
plt.imshow(images[0])

plt.subplot(1,2,2)
plt.imshow(images[1])

plt.show()

# %% [markdown]
# # **Convolution Layer WO Padding**

# %%
conv_layer = tf.keras.layers.Conv2D(filters=32, kernel_size=7) # Padding = 'valid' [Default]
display(conv_layer)

fmaps = conv_layer(images)
fmaps.shape  # Output Shape != Input Shape
# Out:
# <Conv2D name=conv2d_1, built=False>
# TensorShape([2, 64, 114, 32])

# %%
# Display Feature Maps For First Image
display(fmaps[0])
# Out:
# <tf.Tensor: shape=(64, 114, 32), dtype=float32, numpy=
# array([[[ 0.12306308, -0.05232972,  0.04252812, ...,  0.03002135,
#           0.05143488,  0.0109741 ],
#         [ 0.08651312, -0.01064969,  0.06199416, ...,  0.02153335,
#           0.04370851,  0.02942114],
#         [ 0.07067371,  0.0087215 ,  0.08197095, ...,  0.07052593,
#           0.01948454,  0.02343061],
#         ...,
#         [ 0.28515422, -0.09975122,  0.00958474, ...,  0.05247146,
#          -0.07838496,  0.1350354 ],
#         [ 0.28506652, -0.09866619,  0.01082161, ...,  0.05074659,
#          -0.07817159,  0.13384928],
#         [ 0.28584495, -0.09816262,  0.00983502, ...,  0.05031695,
#          -0.07774123,  0.13385187]],
#
#        [[ 0.06490098, -0.01487686, -0.04084671, ...,  0.05033918,
#          -0.02065053, -0.00529122],
#         [ 0.02133516, -0.04296262,  0.03348218, ...,  0.02100524,
#          -0.02669548,  0.09704941],
#         [ 0.07185974, -0.03621475, -0.00574374, ...,  0.05652083,
#          -0.05884439,  0.00832502],
#         ...,
#         [ 0.28463098, -0.09864113,  0.00834546, ...,  0.05031264,
#          -0.07623007,  0.1345629 ],
#         [ 0.2853723 , -0.09756993,  0.00950265, ...,  0.04954651,
#          -0.07536242,  0.13479638],
#         [ 0.28748584, -0.09673315,  0.00790595, ...,  0.05068703,
#          -0.07577481,  0.13449837]],
#
#        [[ 0.07671354,  0.01914602,  0.00971108, ..., -0.00091137,
#          -0.01341551, -0.00419994],
#         [ 0.1075957 ,  0.03372791, -0.03282192, ...,  0.07484861,
#          -0.02004433,  0.0137107 ],
#         [ 0.10172526, -0.06397184, -0.01987522, ...,  0.05614599,
#          -0.01242497,  0.06097084],
#         ...,
#         [ 0.28440958, -0.09689841,  0.00986832, ...,  0.0529876 ,
#          -0.07629337,  0.13570799],
#         [ 0.2868948 , -0.09788532,  0.0090717 , ...,  0.05321821,
#          -0.07673473,  0.13490368],
#         [ 0.28701964, -0.09776425,  0.00828802, ...,  0.05298837,
#          -0.07535461,  0.13519019]],
#
#        ...,
#
#        [[ 0.07791848, -0.05025337, -0.06862723, ...,  0.0337467 ,
#          -0.00788884,  0.05782317],
#         [ 0.07313427, -0.03970484, -0.05527294, ...,  0.08356276,
#           0.01498698,  0.07224943],
#         [ 0.09782678, -0.04651975, -0.0432395 , ...,  0.07840028,
#          -0.00549391,  0.09932308],
#         ...,
#         [ 0.25515187, -0.08177719,  0.01532652, ...,  0.04514622,
#          -0.06226042,  0.11800538],
#         [ 0.26237273, -0.07797887,  0.02074249, ...,  0.03757101,
#          -0.07188867,  0.12277466],
#         [ 0.262934  , -0.08876964,  0.01596819, ...,  0.0290414 ,
#          -0.06574025,  0.12669046]],
#
#        [[ 0.08884352,  0.02465749,  0.02992279, ...,  0.04968692,
#           0.04213671, -0.00901324],
#         [ 0.08694408, -0.00129434,  0.02347142, ...,  0.1030959 ,
#           0.01878849, -0.00033533],
#         [ 0.08081467, -0.01409284,  0.02460968, ...,  0.09445795,
#           0.00537283,  0.00730775],
#         ...,
#         [ 0.2516293 , -0.08977447,  0.00522368, ...,  0.05789997,
#          -0.05911329,  0.13443324],
#         [ 0.2613276 , -0.08313595,  0.01337897, ...,  0.03628876,
#          -0.06500632,  0.12234925],
#         [ 0.25763845, -0.07967275,  0.01541933, ...,  0.04219904,
#          -0.06189144,  0.12017278]],
#
#        [[ 0.09193289, -0.02689856,  0.04088421, ...,  0.05218776,
#          -0.0783175 ,  0.02840246],
#         [ 0.10013843, -0.08558898,  0.02684772, ...,  0.06536969,
#          -0.09484687,  0.03086848],
#         [ 0.10276841, -0.09681155,  0.04658365, ...,  0.04767981,
#          -0.06557784,  0.02959932],
#         ...,
#         [ 0.24870327, -0.08281551,  0.01604789, ...,  0.06786288,
#          -0.06103762,  0.13007596],
#         [ 0.26712397, -0.08302087,  0.0276611 , ...,  0.04713615,
#          -0.06392217,  0.12465996],
#         [ 0.2681161 , -0.08380785,  0.02164015, ...,  0.04171422,
#          -0.06389105,  0.12779978]]], dtype=float32)>

# %% [markdown]
# # **Convolution Layer WT Padding**

# %%
conv_layer = tf.keras.layers.Conv2D(filters=32, kernel_size=7,padding='same')
display(conv_layer)

fmaps = conv_layer(images)
fmaps.shape  # Output Shape = Input Shape
# Out:
# <Conv2D name=conv2d_2, built=False>
# TensorShape([2, 70, 120, 32])

# %% [markdown]
# # **Using Pre-Trained Models**

# %%
import tensorflow_datasets as tfds

dataset, info = tfds.load('tf_flowers', as_supervised=True, with_info=True)
