# %% [markdown]
# # **Setup**
#
# * https://www.kaggle.com/datasets/aadharshviswanath/aircraft-sensor-and-engine-performance

# %%
# !python --version

from psutil import *
print(f'CPU Cores: {cpu_count()}')
print(f'System Memory: {virtual_memory()[0]/(1024**3)} GB')
# Out:
# Python 3.11.6
# CPU Cores: 16
# System Memory: 15.692092895507812 GB

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

import os 
from zipfile import ZipFile
from IPython.display import clear_output

# %% [markdown]
# # **Data Import**

# %% [markdown]
# ## **Download & Extract**

# %%
# !kaggle datasets download -d aadharshviswanath/aircraft-sensor-and-engine-performance --unzip
# Out:
# ...
#   0%|          | 0.00/6.29M [00:00<?, ?B/s]
#  16%|█▌        | 1.00M/6.29M [00:00<00:02, 1.92MB/s]
#  32%|███▏      | 2.00M/6.29M [00:00<00:01, 2.43MB/s]
#  48%|████▊     | 3.00M/6.29M [00:01<00:01, 2.87MB/s]
#  64%|██████▎   | 4.00M/6.29M [00:01<00:00, 3.05MB/s]
#  80%|███████▉  | 5.00M/6.29M [00:01<00:00, 3.29MB/s]
#  95%|█████████▌| 6.00M/6.29M [00:02<00:00, 3.45MB/s]
# 100%|██████████| 6.29M/6.29M [00:02<00:00, 3.09MB/s]
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\aksha\AppData\Local\Programs\Python\Python311\Scripts\kaggle.exe\__main__.py", line 7, in <module>
#   File "C:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\kaggle\cli.py", line 70, in main
#     out = args.func(**command_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# ## **Load Data - Train**

# %%
df_train = pd.read_excel('Dataset/PM_train.xlsx')

print(df_train.shape)
print(df_train.columns)
df_train.head()
# Out:
# (20631, 26)
# Index(['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
#        's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
#        's15', 's16', 's17', 's18', 's19', 's20', 's21'],
#       dtype='object')
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004       100  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003       100  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003       100  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000       100  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002       100  518.67  642.37  1582.85  1406.22
#
#       s5  ...     s12      s13      s14     s15   s16  s17   s18  s19    s20  \
# 0  14.62  ...  521.66  2388.02  8138.62  8.4195  0.03  392  2388  100  39.06
# 1  14.62  ...  522.28  2388.07  8131.49  8.4318  0.03  392  2388  100  39.00
# ...

# %% [markdown]
# ## **Load Data - Test**

# %%
df_test = pd.read_excel('Dataset/PM_test.xlsx')

print(df_test.shape)
print(df_test.columns)
df_test.head()
# Out:
# (11939, 26)
# Index(['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
#        's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
#        's15', 's16', 's17', 's18', 's19', 's20', 's21'],
#       dtype='object')
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1    0.0023    0.0003       100  518.67  643.02  1585.29  1398.21
# 1   1      2   -0.0027   -0.0003       100  518.67  641.71  1588.45  1395.42
# 2   1      3    0.0003    0.0001       100  518.67  642.46  1586.94  1401.34
# 3   1      4    0.0042    0.0000       100  518.67  642.44  1584.12  1406.42
# 4   1      5    0.0014    0.0000       100  518.67  642.51  1587.19  1401.92
#
#       s5  ...     s12      s13      s14     s15   s16    s17   s18  s19  \
# 0  14.62  ...  521.72  2388.03  8125.55  8.4052  0.03  392.0  2388  100
# 1  14.62  ...  522.16  2388.06  8139.62  8.3803  0.03  393.0  2388  100
# ...

# %% [markdown]
# ## **Load Truth Data**

# %%
df_truth = pd.read_excel('Dataset/PM_truth.xlsx')

print(df_truth.shape)
print(df_truth.columns)
df_truth.head()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_truth = pd.read_excel('Dataset/PM_truth.xlsx')
#       3 print(df_truth.shape)
#       4 print(df_truth.columns)
#
# File c:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
# ...

# %% [markdown]
# ## **Merge Data**

# %%
df = pd.concat([df_train,df_])
